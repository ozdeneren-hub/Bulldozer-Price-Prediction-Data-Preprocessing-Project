# %% [markdown]
# # 🚜 Predicting the Sale Price of Bulldozers using Machine Learning
#
# In this notebook, we're going to go through an example machine learning project with the goal of predicting the sale price of bulldozers.
#
# Since we're trying to predict a number, this kind of problem is known as a **regression problem**.
#
# The data and evaluation metric we'll be using (root mean square log error or RMSLE) is from the [Kaggle Bluebook for Bulldozers competition](https://www.kaggle.com/c/bluebook-for-bulldozers/overview).

# %% [markdown]
# ## 1. Problem Definition
#
# For this dataset, the problem we're trying to solve, or better, the question we're trying to answer is,
#
# > How well can we predict the future sale price of a bulldozer, given its characteristics previous examples of how much similar bulldozers have been sold for?
#
# ## 2. Data
#
# Looking at the [dataset from Kaggle](https://www.kaggle.com/c/bluebook-for-bulldozers/data), you can you it's a time series problem. This means there's a time attribute to dataset.
#
# In this case, it's historical sales data of bulldozers. Including things like, model type, size, sale date and more.
#
# **Bulldozer.csv** - Historical bulldozer sales examples up to 2012 (close to 400,000 examples with 50+ different attributes, including `SalePrice` which is the **target variable**).
#
# ## 3. Evaluation
#
# For this problem, [Kaggle has set the evaluation metric to being root mean squared log error (RMSLE)](https://www.kaggle.com/c/bluebook-for-bulldozers/overview/evaluation). As with many regression evaluations, the goal will be to get this value as low as possible.
#
# To see how well our model is doing, we'll calculate the RMSLE and then compare our results to others on the [Kaggle leaderboard](https://www.kaggle.com/c/bluebook-for-bulldozers/leaderboard).
#
# ## 4. Features
#
# Features are different parts of the data. During this step, you'll want to start finding out what you can about the data.
#
# One of the most common ways to do this, is to create a **data dictionary**.
#
# For this dataset, Kaggle provide a data dictionary which contains information about what each attribute of the dataset means. You can [download this file directly from the Kaggle competition page](https://www.kaggle.com/c/bluebook-for-bulldozers/download/Bnl6RAHA0enbg0UfAvGA%2Fversions%2FwBG4f35Q8mAbfkzwCeZn%2Ffiles%2FData%20Dictionary.xlsx) (account required) or view it on Google Sheets.
#
# With all of this being known, let's get started!
#
#
# ### Importing the data and preparing it for modelling

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./data/Bulldozer.csv", low_memory=False, index_col= 0)
data.head()
# Out:
#          SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# SalesID
# 1139246    66000.0     999089     3157         121           3.0      2004
# 1139248    57000.0     117657       77         121           3.0      1996
# 1139249    10000.0     434808     7009         121           3.0      2001
# 1139251    38500.0    1026470      332         121           3.0      2001
# 1139253    11000.0    1057373    17311         121           3.0      2007
#
#          MachineHoursCurrentMeter UsageBand         saledate fiModelDesc  ...  \
# SalesID                                                                   ...
# 1139246                      68.0       Low  11/16/2006 0:00        521D  ...
# 1139248                    4640.0       Low   3/26/2004 0:00      950FII  ...
# 1139249                    2838.0      High   2/26/2004 0:00         226  ...
# 1139251                    3486.0      High   5/19/2011 0:00    PC120-6E  ...
# 1139253                     722.0    Medium   7/23/2009 0:00        S175  ...
#
#         Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer  \
# SalesID
# 1139246                     NaN          NaN   NaN             NaN
# 1139248                     NaN          NaN   NaN             NaN
# 1139249                     NaN          NaN   NaN             NaN
# 1139251                     NaN          NaN   NaN             NaN
# 1139253                     NaN          NaN   NaN             NaN
#
#         Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# SalesID
# 1139246          NaN              NaN        NaN             NaN
# 1139248          NaN              NaN        NaN             NaN
# 1139249          NaN              NaN        NaN             NaN
# 1139251          NaN              NaN        NaN             NaN
# 1139253          NaN              NaN        NaN             NaN
#
#         Differential_Type Steering_Controls
# SalesID
# 1139246          Standard      Conventional
# 1139248          Standard      Conventional
# 1139249               NaN               NaN
# 1139251               NaN               NaN
# 1139253               NaN               NaN
#
# [5 rows x 52 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412698 entries, 1139246 to 6333349
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalePrice                 412698 non-null  float64
#  1   MachineID                 412698 non-null  int64
#  2   ModelID                   412698 non-null  int64
#  3   datasource                412698 non-null  int64
#  4   auctioneerID              392562 non-null  float64
#  5   YearMade                  412698 non-null  int64
#  6   MachineHoursCurrentMeter  147504 non-null  float64
#  7   UsageBand                 73670 non-null   object
#  8   saledate                  412698 non-null  object
#  9   fiModelDesc               412698 non-null  object
#  10  fiBaseModel               412698 non-null  object
#  11  fiSecondaryDesc           271971 non-null  object
#  12  fiModelSeries             58667 non-null   object
#  13  fiModelDescriptor         74816 non-null   object
#  14  ProductSize               196093 non-null  object
#  15  fiProductClassDesc        412698 non-null  object
#  16  state                     412698 non-null  object
#  17  ProductGroup              412698 non-null  object
#  18  ProductGroupDesc          412698 non-null  object
#  19  Drive_System              107087 non-null  object
#  20  Enclosure                 412364 non-null  object
#  21  Forks                     197715 non-null  object
#  22  Pad_Type                  81096 non-null   object
#  23  Ride_Control              152728 non-null  object
#  24  Stick                     81096 non-null   object
#  25  Transmission              188007 non-null  object
#  26  Turbocharged              81096 non-null   object
#  27  Blade_Extension           25983 non-null   object
#  28  Blade_Width               25983 non-null   object
#  29  Enclosure_Type            25983 non-null   object
#  30  Engine_Horsepower         25983 non-null   object
#  31  Hydraulics                330133 non-null  object
#  32  Pushblock                 25983 non-null   object
#  33  Ripper                    106945 non-null  object
#  34  Scarifier                 25994 non-null   object
#  35  Tip_Control               25983 non-null   object
#  36  Tire_Size                 97638 non-null   object
#  37  Coupler                   220679 non-null  object
#  38  Coupler_System            44974 non-null   object
#  39  Grouser_Tracks            44875 non-null   object
#  40  Hydraulics_Flow           44875 non-null   object
#  41  Track_Type                102193 non-null  object
#  42  Undercarriage_Pad_Width   102916 non-null  object
#  43  Stick_Length              102261 non-null  object
#  44  Thumb                     102332 non-null  object
#  45  Pattern_Changer           102261 non-null  object
#  46  Grouser_Type              102193 non-null  object
#  47  Backhoe_Mounting          80712 non-null   object
#  48  Blade_Type                81875 non-null   object
#  49  Travel_Controls           81877 non-null   object
#  50  Differential_Type         71564 non-null   object
#  51  Steering_Controls         71522 non-null   object
# dtypes: float64(3), int64(4), object(45)
# memory usage: 166.9+ MB

# %%
data = pd.read_csv("./data/Bulldozer.csv", low_memory=False, index_col= 0, parse_dates=["saledate"])
data.head()
# Out:
#          SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# SalesID
# 1139246    66000.0     999089     3157         121           3.0      2004
# 1139248    57000.0     117657       77         121           3.0      1996
# 1139249    10000.0     434808     7009         121           3.0      2001
# 1139251    38500.0    1026470      332         121           3.0      2001
# 1139253    11000.0    1057373    17311         121           3.0      2007
#
#          MachineHoursCurrentMeter UsageBand   saledate fiModelDesc  ...  \
# SalesID                                                             ...
# 1139246                      68.0       Low 2006-11-16        521D  ...
# 1139248                    4640.0       Low 2004-03-26      950FII  ...
# 1139249                    2838.0      High 2004-02-26         226  ...
# 1139251                    3486.0      High 2011-05-19    PC120-6E  ...
# 1139253                     722.0    Medium 2009-07-23        S175  ...
#
#         Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer  \
# SalesID
# 1139246                     NaN          NaN   NaN             NaN
# 1139248                     NaN          NaN   NaN             NaN
# 1139249                     NaN          NaN   NaN             NaN
# 1139251                     NaN          NaN   NaN             NaN
# 1139253                     NaN          NaN   NaN             NaN
#
#         Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# SalesID
# 1139246          NaN              NaN        NaN             NaN
# 1139248          NaN              NaN        NaN             NaN
# 1139249          NaN              NaN        NaN             NaN
# 1139251          NaN              NaN        NaN             NaN
# 1139253          NaN              NaN        NaN             NaN
#
#         Differential_Type Steering_Controls
# SalesID
# 1139246          Standard      Conventional
# 1139248          Standard      Conventional
# 1139249               NaN               NaN
# 1139251               NaN               NaN
# 1139253               NaN               NaN
#
# [5 rows x 52 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412698 entries, 1139246 to 6333349
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalePrice                 412698 non-null  float64
#  1   MachineID                 412698 non-null  int64
#  2   ModelID                   412698 non-null  int64
#  3   datasource                412698 non-null  int64
#  4   auctioneerID              392562 non-null  float64
#  5   YearMade                  412698 non-null  int64
#  6   MachineHoursCurrentMeter  147504 non-null  float64
#  7   UsageBand                 73670 non-null   object
#  8   saledate                  412698 non-null  datetime64[ns]
#  9   fiModelDesc               412698 non-null  object
#  10  fiBaseModel               412698 non-null  object
#  11  fiSecondaryDesc           271971 non-null  object
#  12  fiModelSeries             58667 non-null   object
#  13  fiModelDescriptor         74816 non-null   object
#  14  ProductSize               196093 non-null  object
#  15  fiProductClassDesc        412698 non-null  object
#  16  state                     412698 non-null  object
#  17  ProductGroup              412698 non-null  object
#  18  ProductGroupDesc          412698 non-null  object
#  19  Drive_System              107087 non-null  object
#  20  Enclosure                 412364 non-null  object
#  21  Forks                     197715 non-null  object
#  22  Pad_Type                  81096 non-null   object
#  23  Ride_Control              152728 non-null  object
#  24  Stick                     81096 non-null   object
#  25  Transmission              188007 non-null  object
#  26  Turbocharged              81096 non-null   object
#  27  Blade_Extension           25983 non-null   object
#  28  Blade_Width               25983 non-null   object
#  29  Enclosure_Type            25983 non-null   object
#  30  Engine_Horsepower         25983 non-null   object
#  31  Hydraulics                330133 non-null  object
#  32  Pushblock                 25983 non-null   object
#  33  Ripper                    106945 non-null  object
#  34  Scarifier                 25994 non-null   object
#  35  Tip_Control               25983 non-null   object
#  36  Tire_Size                 97638 non-null   object
#  37  Coupler                   220679 non-null  object
#  38  Coupler_System            44974 non-null   object
#  39  Grouser_Tracks            44875 non-null   object
#  40  Hydraulics_Flow           44875 non-null   object
#  41  Track_Type                102193 non-null  object
#  42  Undercarriage_Pad_Width   102916 non-null  object
#  43  Stick_Length              102261 non-null  object
#  44  Thumb                     102332 non-null  object
#  45  Pattern_Changer           102261 non-null  object
#  46  Grouser_Type              102193 non-null  object
#  47  Backhoe_Mounting          80712 non-null   object
#  48  Blade_Type                81875 non-null   object
#  49  Travel_Controls           81877 non-null   object
#  50  Differential_Type         71564 non-null   object
#  51  Steering_Controls         71522 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(44)
# memory usage: 166.9+ MB

# %%
data.sort_values(by="saledate", inplace=True)
data.head()
# Out:
#          SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# SalesID
# 1646770     9500.0    1126363     8434         132          18.0      1974
# 1821514    14000.0    1194089    10150         132          99.0      1980
# 1505138    50000.0    1473654     4139         132          99.0      1978
# 1671174    16000.0    1327630     8591         132          99.0      1980
# 1329056    22000.0    1336053     4089         132          99.0      1984
#
#          MachineHoursCurrentMeter UsageBand   saledate fiModelDesc  ...  \
# SalesID                                                             ...
# 1646770                       NaN       NaN 1989-01-17        TD20  ...
# 1821514                       NaN       NaN 1989-01-31         A66  ...
# 1505138                       NaN       NaN 1989-01-31         D7G  ...
# 1671174                       NaN       NaN 1989-01-31         A62  ...
# 1329056                       NaN       NaN 1989-01-31         D3B  ...
#
#         Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer  \
# SalesID
# 1646770                     NaN          NaN   NaN             NaN
# 1821514                     NaN          NaN   NaN             NaN
# 1505138                     NaN          NaN   NaN             NaN
# 1671174                     NaN          NaN   NaN             NaN
# 1329056                     NaN          NaN   NaN             NaN
#
#         Grouser_Type     Backhoe_Mounting Blade_Type      Travel_Controls  \
# SalesID
# 1646770          NaN  None or Unspecified   Straight  None or Unspecified
# 1821514          NaN                  NaN        NaN                  NaN
# 1505138          NaN  None or Unspecified   Straight  None or Unspecified
# 1671174          NaN                  NaN        NaN                  NaN
# 1329056          NaN  None or Unspecified        PAT                Lever
#
#         Differential_Type Steering_Controls
# SalesID
# 1646770               NaN               NaN
# 1821514          Standard      Conventional
# 1505138               NaN               NaN
# 1671174          Standard      Conventional
# 1329056               NaN               NaN
#
# [5 rows x 52 columns]

# %%
data["sale_year"] = data.saledate.dt.year
data["sale_month"] = data.saledate.dt.month
data["sale_day"] = data.saledate.dt.day

data.head()
# Out:
#          SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# SalesID
# 1646770     9500.0    1126363     8434         132          18.0      1974
# 1821514    14000.0    1194089    10150         132          99.0      1980
# 1505138    50000.0    1473654     4139         132          99.0      1978
# 1671174    16000.0    1327630     8591         132          99.0      1980
# 1329056    22000.0    1336053     4089         132          99.0      1984
#
#          MachineHoursCurrentMeter UsageBand   saledate fiModelDesc  ...  \
# SalesID                                                             ...
# 1646770                       NaN       NaN 1989-01-17        TD20  ...
# 1821514                       NaN       NaN 1989-01-31         A66  ...
# 1505138                       NaN       NaN 1989-01-31         D7G  ...
# 1671174                       NaN       NaN 1989-01-31         A62  ...
# 1329056                       NaN       NaN 1989-01-31         D3B  ...
#
#         Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# SalesID
# 1646770             NaN          NaN  None or Unspecified   Straight
# 1821514             NaN          NaN                  NaN        NaN
# 1505138             NaN          NaN  None or Unspecified   Straight
# 1671174             NaN          NaN                  NaN        NaN
# 1329056             NaN          NaN  None or Unspecified        PAT
#
#              Travel_Controls Differential_Type Steering_Controls sale_year  \
# SalesID
# 1646770  None or Unspecified               NaN               NaN      1989
# 1821514                  NaN          Standard      Conventional      1989
# 1505138  None or Unspecified               NaN               NaN      1989
# 1671174                  NaN          Standard      Conventional      1989
# 1329056                Lever               NaN               NaN      1989
#
#         sale_month sale_day
# SalesID
# 1646770          1       17
# 1821514          1       31
# 1505138          1       31
# 1671174          1       31
# 1329056          1       31
#
# [5 rows x 55 columns]

# %%
data["sale_day_of_year"] = data.saledate.dt.day_of_year
data["sale_day_of_week"] = data.saledate.dt.day_of_week
data.head()
# Out:
#          SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# SalesID
# 1646770     9500.0    1126363     8434         132          18.0      1974
# 1821514    14000.0    1194089    10150         132          99.0      1980
# 1505138    50000.0    1473654     4139         132          99.0      1978
# 1671174    16000.0    1327630     8591         132          99.0      1980
# 1329056    22000.0    1336053     4089         132          99.0      1984
#
#          MachineHoursCurrentMeter UsageBand   saledate fiModelDesc  ...  \
# SalesID                                                             ...
# 1646770                       NaN       NaN 1989-01-17        TD20  ...
# 1821514                       NaN       NaN 1989-01-31         A66  ...
# 1505138                       NaN       NaN 1989-01-31         D7G  ...
# 1671174                       NaN       NaN 1989-01-31         A62  ...
# 1329056                       NaN       NaN 1989-01-31         D3B  ...
#
#             Backhoe_Mounting Blade_Type      Travel_Controls  \
# SalesID
# 1646770  None or Unspecified   Straight  None or Unspecified
# 1821514                  NaN        NaN                  NaN
# 1505138  None or Unspecified   Straight  None or Unspecified
# 1671174                  NaN        NaN                  NaN
# 1329056  None or Unspecified        PAT                Lever
#
#         Differential_Type Steering_Controls sale_year sale_month sale_day  \
# SalesID
# 1646770               NaN               NaN      1989          1       17
# 1821514          Standard      Conventional      1989          1       31
# 1505138               NaN               NaN      1989          1       31
# 1671174          Standard      Conventional      1989          1       31
# 1329056               NaN               NaN      1989          1       31
#
#         sale_day_of_year sale_day_of_week
# SalesID
# 1646770               17                1
# 1821514               31                1
# 1505138               31                1
# 1671174               31                1
# 1329056               31                1
#
# [5 rows x 57 columns]

# %%
del data["saledate"]

# %%
data.head()
# Out:
#          SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# SalesID
# 1646770     9500.0    1126363     8434         132          18.0      1974
# 1821514    14000.0    1194089    10150         132          99.0      1980
# 1505138    50000.0    1473654     4139         132          99.0      1978
# 1671174    16000.0    1327630     8591         132          99.0      1980
# 1329056    22000.0    1336053     4089         132          99.0      1984
#
#          MachineHoursCurrentMeter UsageBand fiModelDesc fiBaseModel  ...  \
# SalesID                                                              ...
# 1646770                       NaN       NaN        TD20        TD20  ...
# 1821514                       NaN       NaN         A66         A66  ...
# 1505138                       NaN       NaN         D7G          D7  ...
# 1671174                       NaN       NaN         A62         A62  ...
# 1329056                       NaN       NaN         D3B          D3  ...
#
#             Backhoe_Mounting Blade_Type      Travel_Controls  \
# SalesID
# 1646770  None or Unspecified   Straight  None or Unspecified
# 1821514                  NaN        NaN                  NaN
# 1505138  None or Unspecified   Straight  None or Unspecified
# 1671174                  NaN        NaN                  NaN
# 1329056  None or Unspecified        PAT                Lever
#
#         Differential_Type Steering_Controls sale_year sale_month sale_day  \
# SalesID
# 1646770               NaN               NaN      1989          1       17
# 1821514          Standard      Conventional      1989          1       31
# 1505138               NaN               NaN      1989          1       31
# 1671174          Standard      Conventional      1989          1       31
# 1329056               NaN               NaN      1989          1       31
#
#         sale_day_of_year sale_day_of_week
# SalesID
# 1646770               17                1
# 1821514               31                1
# 1505138               31                1
# 1671174               31                1
# 1329056               31                1
#
# [5 rows x 56 columns]

# %%
pd.api.types.is_string_dtype(data.UsageBand)
# Out:
# True

# %%
for col_name, content in data.iteritems():
    if pd.api.types.is_string_dtype(content):
        data[col_name] = content.astype("category")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412698 entries, 1646770 to 6283635
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalePrice                 412698 non-null  float64
#  1   MachineID                 412698 non-null  int64
#  2   ModelID                   412698 non-null  int64
#  3   datasource                412698 non-null  int64
#  4   auctioneerID              392562 non-null  float64
#  5   YearMade                  412698 non-null  int64
#  6   MachineHoursCurrentMeter  147504 non-null  float64
#  7   UsageBand                 73670 non-null   category
#  8   fiModelDesc               412698 non-null  category
#  9   fiBaseModel               412698 non-null  category
#  10  fiSecondaryDesc           271971 non-null  category
#  11  fiModelSeries             58667 non-null   category
#  12  fiModelDescriptor         74816 non-null   category
#  13  ProductSize               196093 non-null  category
#  14  fiProductClassDesc        412698 non-null  category
#  15  state                     412698 non-null  category
#  16  ProductGroup              412698 non-null  category
#  17  ProductGroupDesc          412698 non-null  category
#  18  Drive_System              107087 non-null  category
#  19  Enclosure                 412364 non-null  category
#  20  Forks                     197715 non-null  category
#  21  Pad_Type                  81096 non-null   category
#  22  Ride_Control              152728 non-null  category
#  23  Stick                     81096 non-null   category
#  24  Transmission              188007 non-null  category
#  25  Turbocharged              81096 non-null   category
#  26  Blade_Extension           25983 non-null   category
#  27  Blade_Width               25983 non-null   category
#  28  Enclosure_Type            25983 non-null   category
#  29  Engine_Horsepower         25983 non-null   category
#  30  Hydraulics                330133 non-null  category
#  31  Pushblock                 25983 non-null   category
#  32  Ripper                    106945 non-null  category
#  33  Scarifier                 25994 non-null   category
#  34  Tip_Control               25983 non-null   category
#  35  Tire_Size                 97638 non-null   category
#  36  Coupler                   220679 non-null  category
#  37  Coupler_System            44974 non-null   category
#  38  Grouser_Tracks            44875 non-null   category
#  39  Hydraulics_Flow           44875 non-null   category
#  40  Track_Type                102193 non-null  category
#  41  Undercarriage_Pad_Width   102916 non-null  category
#  42  Stick_Length              102261 non-null  category
#  43  Thumb                     102332 non-null  category
#  44  Pattern_Changer           102261 non-null  category
#  45  Grouser_Type              102193 non-null  category
#  46  Backhoe_Mounting          80712 non-null   category
#  47  Blade_Type                81875 non-null   category
#  48  Travel_Controls           81877 non-null   category
#  49  Differential_Type         71564 non-null   category
#  50  Steering_Controls         71522 non-null   category
#  51  sale_year                 412698 non-null  int64
#  52  sale_month                412698 non-null  int64
#  53  sale_day                  412698 non-null  int64
#  54  sale_day_of_year          412698 non-null  int64
#  55  sale_day_of_week          412698 non-null  int64
# dtypes: category(44), float64(3), int64(9)
# memory usage: 60.1 MB

# %%
data.Backhoe_Mounting.cat.categories
# Out:
# Index(['None or Unspecified', 'Yes'], dtype='object')

# %%
data.Blade_Type.cat.categories
# Out:
# Index(['Angle', 'Coal', 'Landfill', 'No', 'None or Unspecified', 'PAT',
#        'Semi U', 'Straight', 'U', 'VPAT'],
#       dtype='object')

# %%
data.Blade_Type.cat.codes
# Out:
# SalesID
# 1646770    7
# 1821514   -1
# 1505138    7
# 1671174   -1
# 1329056    5
#           ..
# 6302984    5
# 6324811   -1
# 6313029   -1
# 6266251   -1
# 6283635   -1
# Length: 412698, dtype: int8

# %%
for col_name, content in data.iteritems():
    if pd.api.types.is_categorical_dtype(content):
        data[col_name] = content.cat.codes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412698 entries, 1646770 to 6283635
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalePrice                 412698 non-null  float64
#  1   MachineID                 412698 non-null  int64
#  2   ModelID                   412698 non-null  int64
#  3   datasource                412698 non-null  int64
#  4   auctioneerID              392562 non-null  float64
#  5   YearMade                  412698 non-null  int64
#  6   MachineHoursCurrentMeter  147504 non-null  float64
#  7   UsageBand                 412698 non-null  int8
#  8   fiModelDesc               412698 non-null  int16
#  9   fiBaseModel               412698 non-null  int16
#  10  fiSecondaryDesc           412698 non-null  int16
#  11  fiModelSeries             412698 non-null  int8
#  12  fiModelDescriptor         412698 non-null  int16
#  13  ProductSize               412698 non-null  int8
#  14  fiProductClassDesc        412698 non-null  int8
#  15  state                     412698 non-null  int8
#  16  ProductGroup              412698 non-null  int8
#  17  ProductGroupDesc          412698 non-null  int8
#  18  Drive_System              412698 non-null  int8
#  19  Enclosure                 412698 non-null  int8
#  20  Forks                     412698 non-null  int8
#  21  Pad_Type                  412698 non-null  int8
#  22  Ride_Control              412698 non-null  int8
#  23  Stick                     412698 non-null  int8
#  24  Transmission              412698 non-null  int8
#  25  Turbocharged              412698 non-null  int8
#  26  Blade_Extension           412698 non-null  int8
#  27  Blade_Width               412698 non-null  int8
#  28  Enclosure_Type            412698 non-null  int8
#  29  Engine_Horsepower         412698 non-null  int8
#  30  Hydraulics                412698 non-null  int8
#  31  Pushblock                 412698 non-null  int8
#  32  Ripper                    412698 non-null  int8
#  33  Scarifier                 412698 non-null  int8
#  34  Tip_Control               412698 non-null  int8
#  35  Tire_Size                 412698 non-null  int8
#  36  Coupler                   412698 non-null  int8
#  37  Coupler_System            412698 non-null  int8
#  38  Grouser_Tracks            412698 non-null  int8
#  39  Hydraulics_Flow           412698 non-null  int8
#  40  Track_Type                412698 non-null  int8
#  41  Undercarriage_Pad_Width   412698 non-null  int8
#  42  Stick_Length              412698 non-null  int8
#  43  Thumb                     412698 non-null  int8
#  44  Pattern_Changer           412698 non-null  int8
#  45  Grouser_Type              412698 non-null  int8
#  46  Backhoe_Mounting          412698 non-null  int8
#  47  Blade_Type                412698 non-null  int8
#  48  Travel_Controls           412698 non-null  int8
#  49  Differential_Type         412698 non-null  int8
#  50  Steering_Controls         412698 non-null  int8
#  51  sale_year                 412698 non-null  int64
#  52  sale_month                412698 non-null  int64
#  53  sale_day                  412698 non-null  int64
#  54  sale_day_of_year          412698 non-null  int64
#  55  sale_day_of_week          412698 non-null  int64
# dtypes: float64(3), int16(4), int64(9), int8(40)
# memory usage: 59.8 MB

# %%
data["auctioneerID_imputed"] = data.auctioneerID.isna()
data["MachineHoursCurrentMeter_imputed"] = data.MachineHoursCurrentMeter.isna()

data.head()
# Out:
#          SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# SalesID
# 1646770     9500.0    1126363     8434         132          18.0      1974
# 1821514    14000.0    1194089    10150         132          99.0      1980
# 1505138    50000.0    1473654     4139         132          99.0      1978
# 1671174    16000.0    1327630     8591         132          99.0      1980
# 1329056    22000.0    1336053     4089         132          99.0      1984
#
#          MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# SalesID                                                                 ...
# 1646770                       NaN         -1         4592         1743  ...
# 1821514                       NaN         -1         1819          558  ...
# 1505138                       NaN         -1         2347          712  ...
# 1671174                       NaN         -1         1818          557  ...
# 1329056                       NaN         -1         2118          682  ...
#
#          Travel_Controls  Differential_Type  Steering_Controls  sale_year  \
# SalesID
# 1646770                5                 -1                 -1       1989
# 1821514               -1                  3                  1       1989
# 1505138                5                 -1                 -1       1989
# 1671174               -1                  3                  1       1989
# 1329056                4                 -1                 -1       1989
#
#          sale_month  sale_day  sale_day_of_year  sale_day_of_week  \
# SalesID
# 1646770           1        17                17                 1
# 1821514           1        31                31                 1
# 1505138           1        31                31                 1
# 1671174           1        31                31                 1
# 1329056           1        31                31                 1
#
#          auctioneerID_imputed  MachineHoursCurrentMeter_imputed
# SalesID
# 1646770                 False                              True
# 1821514                 False                              True
# 1505138                 False                              True
# 1671174                 False                              True
# 1329056                 False                              True
#
# [5 rows x 58 columns]

# %%
data.MachineHoursCurrentMeter.iloc[data.MachineHoursCurrentMeter.isna()] = data.MachineHoursCurrentMeter.mean()
data.head()
# Out:
# C:\Users\ergun\AppData\Local\Temp\ipykernel_24236\439443355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.MachineHoursCurrentMeter.iloc[data.MachineHoursCurrentMeter.isna()] = data.MachineHoursCurrentMeter.mean()
#          SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# SalesID
# 1646770     9500.0    1126363     8434         132          18.0      1974
# 1821514    14000.0    1194089    10150         132          99.0      1980
# 1505138    50000.0    1473654     4139         132          99.0      1978
# 1671174    16000.0    1327630     8591         132          99.0      1980
# 1329056    22000.0    1336053     4089         132          99.0      1984
#
#          MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# SalesID                                                                 ...
# 1646770               3522.988285         -1         4592         1743  ...
# 1821514               3522.988285         -1         1819          558  ...
# 1505138               3522.988285         -1         2347          712  ...
# 1671174               3522.988285         -1         1818          557  ...
# 1329056               3522.988285         -1         2118          682  ...
#
#          Travel_Controls  Differential_Type  Steering_Controls  sale_year  \
# SalesID
# 1646770                5                 -1                 -1       1989
# 1821514               -1                  3                  1       1989
# 1505138                5                 -1                 -1       1989
# 1671174               -1                  3                  1       1989
# 1329056                4                 -1                 -1       1989
#
#          sale_month  sale_day  sale_day_of_year  sale_day_of_week  \
# SalesID
# 1646770           1        17                17                 1
# 1821514           1        31                31                 1
# 1505138           1        31                31                 1
# 1671174           1        31                31                 1
# 1329056           1        31                31                 1
#
#          auctioneerID_imputed  MachineHoursCurrentMeter_imputed
# SalesID
# 1646770                 False                              True
# 1821514                 False                              True
# 1505138                 False                              True
# 1671174                 False                              True
# 1329056                 False                              True
#
# [5 rows x 58 columns]

# %%
data.auctioneerID.value_counts()
# Out:
# 1.0     192773
# 2.0      57441
# 3.0      30288
# 4.0      20877
# 99.0     12042
# 6.0      11950
# 7.0       7847
# 8.0       7419
# 5.0       7002
# 10.0      5876
# 9.0       4764
# 11.0      3823
# 12.0      3610
# 13.0      3068
# 18.0      2359
# 14.0      2277
# 20.0      2238
# 19.0      2074
# 16.0      1807
# 15.0      1742
# 21.0      1601
# 22.0      1429
# 24.0      1357
# 23.0      1322
# 17.0      1275
# 27.0      1150
# 25.0       959
# 28.0       860
# 26.0       796
# 0.0        536
# Name: auctioneerID, dtype: int64

# %%
data.auctioneerID.iloc[data.auctioneerID.isna()] = 1.0
# Out:
# C:\Users\ergun\AppData\Local\Temp\ipykernel_24236\3943589175.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.auctioneerID.iloc[data.auctioneerID.isna()] = 1.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412698 entries, 1646770 to 6283635
# Data columns (total 58 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   SalePrice                         412698 non-null  float64
#  1   MachineID                         412698 non-null  int64
#  2   ModelID                           412698 non-null  int64
#  3   datasource                        412698 non-null  int64
#  4   auctioneerID                      412698 non-null  float64
#  5   YearMade                          412698 non-null  int64
#  6   MachineHoursCurrentMeter          412698 non-null  float64
#  7   UsageBand                         412698 non-null  int8
#  8   fiModelDesc                       412698 non-null  int16
#  9   fiBaseModel                       412698 non-null  int16
#  10  fiSecondaryDesc                   412698 non-null  int16
#  11  fiModelSeries                     412698 non-null  int8
#  12  fiModelDescriptor                 412698 non-null  int16
#  13  ProductSize                       412698 non-null  int8
#  14  fiProductClassDesc                412698 non-null  int8
#  15  state                             412698 non-null  int8
#  16  ProductGroup                      412698 non-null  int8
#  17  ProductGroupDesc                  412698 non-null  int8
#  18  Drive_System                      412698 non-null  int8
#  19  Enclosure                         412698 non-null  int8
#  20  Forks                             412698 non-null  int8
#  21  Pad_Type                          412698 non-null  int8
#  22  Ride_Control                      412698 non-null  int8
#  23  Stick                             412698 non-null  int8
#  24  Transmission                      412698 non-null  int8
#  25  Turbocharged                      412698 non-null  int8
#  26  Blade_Extension                   412698 non-null  int8
#  27  Blade_Width                       412698 non-null  int8
#  28  Enclosure_Type                    412698 non-null  int8
#  29  Engine_Horsepower                 412698 non-null  int8
#  30  Hydraulics                        412698 non-null  int8
#  31  Pushblock                         412698 non-null  int8
#  32  Ripper                            412698 non-null  int8
#  33  Scarifier                         412698 non-null  int8
#  34  Tip_Control                       412698 non-null  int8
#  35  Tire_Size                         412698 non-null  int8
#  36  Coupler                           412698 non-null  int8
#  37  Coupler_System                    412698 non-null  int8
#  38  Grouser_Tracks                    412698 non-null  int8
#  39  Hydraulics_Flow                   412698 non-null  int8
#  40  Track_Type                        412698 non-null  int8
#  41  Undercarriage_Pad_Width           412698 non-null  int8
#  42  Stick_Length                      412698 non-null  int8
#  43  Thumb                             412698 non-null  int8
#  44  Pattern_Changer                   412698 non-null  int8
#  45  Grouser_Type                      412698 non-null  int8
#  46  Backhoe_Mounting                  412698 non-null  int8
#  47  Blade_Type                        412698 non-null  int8
#  48  Travel_Controls                   412698 non-null  int8
#  49  Differential_Type                 412698 non-null  int8
#  50  Steering_Controls                 412698 non-null  int8
#  51  sale_year                         412698 non-null  int64
#  52  sale_month                        412698 non-null  int64
#  53  sale_day                          412698 non-null  int64
#  54  sale_day_of_year                  412698 non-null  int64
#  55  sale_day_of_week                  412698 non-null  int64
#  56  auctioneerID_imputed              412698 non-null  bool
#  57  MachineHoursCurrentMeter_imputed  412698 non-null  bool
# dtypes: bool(2), float64(3), int16(4), int64(9), int8(40)
# memory usage: 60.6 MB

# %%
pd.__version__
# Out:
# '1.4.4'

# %% [markdown]
# ## Model Building

# %%
X_train = data.loc[data.sale_year < 2012, "MachineID":] 
X_test = data.loc[data.sale_year == 2012, "MachineID":] 

y_train = data.loc[data.sale_year < 2012, "SalePrice"] 
y_test = data.loc[data.sale_year == 2012, "SalePrice"] 

X_train.head()
# Out:
#          MachineID  ModelID  datasource  auctioneerID  YearMade  \
# SalesID
# 1646770    1126363     8434         132          18.0      1974
# 1821514    1194089    10150         132          99.0      1980
# 1505138    1473654     4139         132          99.0      1978
# 1671174    1327630     8591         132          99.0      1980
# 1329056    1336053     4089         132          99.0      1984
#
#          MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  \
# SalesID
# 1646770               3522.988285         -1         4592         1743
# 1821514               3522.988285         -1         1819          558
# 1505138               3522.988285         -1         2347          712
# 1671174               3522.988285         -1         1818          557
# 1329056               3522.988285         -1         2118          682
#
#          fiSecondaryDesc  ...  Travel_Controls  Differential_Type  \
# SalesID                   ...
# 1646770               -1  ...                5                 -1
# 1821514               -1  ...               -1                  3
# 1505138               58  ...                5                 -1
# 1671174               -1  ...               -1                  3
# 1329056               20  ...                4                 -1
#
#          Steering_Controls  sale_year  sale_month  sale_day  sale_day_of_year  \
# SalesID
# 1646770                 -1       1989           1        17                17
# 1821514                  1       1989           1        31                31
# 1505138                 -1       1989           1        31                31
# 1671174                  1       1989           1        31                31
# 1329056                 -1       1989           1        31                31
#
#          sale_day_of_week  auctioneerID_imputed  \
# SalesID
# 1646770                 1                 False
# 1821514                 1                 False
# 1505138                 1                 False
# 1671174                 1                 False
# 1329056                 1                 False
#
#          MachineHoursCurrentMeter_imputed
# SalesID
# 1646770                              True
# 1821514                              True
# 1505138                              True
# 1671174                              True
# 1329056                              True
#
# [5 rows x 57 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

learner = RandomForestRegressor(n_jobs=-1)

# %%
# %%time
learner.fit(X_train, y_train)
# Out:
# CPU times: total: 20min 3s
# Wall time: 1min 29s
# RandomForestRegressor(n_jobs=-1)

# %%
import sklearn
sklearn.__version__
# Out:
# '1.2.2'

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_log_error, r2_score

def rmsle(y_true, y_pred):
    return np.sqrt(mean_squared_log_error(y_true,y_pred))

# %%
pred = learner.predict(X_test)
rmsle(y_test, pred)
# Out:
# 0.2546388238905036

# %%
def CalculatePerformance(model, X_train, X_test, y_train, y_test):
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)
    
    results = {"Train R2": r2_score(y_train, pred_train),
               "Test R2": r2_score(y_test, pred_test),
              "Train MAE": mean_absolute_error(y_train, pred_train),
               "Test MAE": mean_absolute_error(y_test, pred_test),
              "Train RMSLE": rmsle(y_train, pred_train),
               "Test RMSLE": rmsle(y_test, pred_test)}
    return results

# %%
CalculatePerformance(learner, X_train, X_test, y_train, y_test)
# Out:
# {'Train R2': 0.9875741470733904,
#  'Test R2': 0.8719247745806851,
#  'Train MAE': 1573.7602620878781,
#  'Test MAE': 6114.057707595264,
#  'Train RMSLE': 0.08436450443453286,
#  'Test RMSLE': 0.2546388238905036}

# %%
learner = RandomForestRegressor(n_jobs= -1, max_samples=30000, random_state= 42)

# %%
# %%time
learner.fit(X_train,y_train)
# Out:
# CPU times: total: 2min 1s
# Wall time: 9.49 s
# RandomForestRegressor(max_samples=30000, n_jobs=-1, random_state=42)

# %%
CalculatePerformance(learner, X_train, X_test, y_train, y_test)
# Out:
# {'Train R2': 0.8978074817788079,
#  'Test R2': 0.8594087748719101,
#  'Train MAE': 4713.605567092552,
#  'Test MAE': 6496.94389181716,
#  'Train RMSLE': 0.224046883608472,
#  'Test RMSLE': 0.2673656024613305}

# %%
params = {
    "n_estimators": [50 ,100, 150,200,250],
    "max_samples": [10000, 20000],
    "max_depth": [None, 5, 10, 20, 30],
    "min_samples_split": [2, 5,10,15],
    "max_features": ["sqrt", 0.5, 0.75, 1.0]
}

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import make_scorer

def neg_rmsle(y_true, y_pred):
    return -1*rmsle(y_true, y_pred)

scorer = make_scorer(neg_rmsle)

search_model = RandomizedSearchCV(RandomForestRegressor(), 
                                 param_distributions=params,
                                 n_iter=5,
                                 scoring=scorer,
                                 cv=5,
                                 n_jobs = -1,
                                 verbose =True)

# %%
# %%time
search_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# CPU times: total: 15.6 s
# Wall time: 1min 22s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=5, n_jobs=-1,
#                    param_distributions={'max_depth': [None, 5, 10, 20, 30],
#                                         'max_features': ['sqrt', 0.5, 0.75,
#                                                          1.0],
#                                         'max_samples': [10000, 20000],
#                                         'min_samples_split': [2, 5, 10, 15],
#                                         'n_estimators': [50, 100, 150, 200,
#                                                          250]},
#                    scoring=make_scorer(neg_rmsle), verbose=True)

# %%
CalculatePerformance(search_model, X_train, X_test, y_train, y_test)
# Out:
# {'Train R2': 0.8711182347114381,
#  'Test R2': 0.8444670363619804,
#  'Train MAE': 5313.526476316312,
#  'Test MAE': 6813.289335306054,
#  'Train RMSLE': 0.2476596653838196,
#  'Test RMSLE': 0.27831470760098115}

# %%
search_model.best_estimator_
# Out:
# RandomForestRegressor(max_depth=20, max_features=0.75, max_samples=30000,
#                       min_samples_split=5, n_estimators=150)

# %%
results = pd.DataFrame(search_model.cv_results_)
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      63.558025      1.255370         2.463284        0.390126
# 1      24.228224      1.604520         0.762476        0.033528
# 2       8.544756      0.390703         1.115842        0.088486
# 3      43.662562      0.569283         6.211806        0.372518
# 4      39.946455      2.221193         0.823410        0.129681
#
#   param_n_estimators param_min_samples_split param_max_samples  \
# 0                200                      10             10000
# 1                100                      15             10000
# 2                 50                      15             20000
# 3                200                       2             20000
# 4                 50                      15             20000
#
#   param_max_features param_max_depth  \
# 0               0.75              30
# 1                1.0               5
# 2               sqrt              10
# 3               sqrt              20
# 4                1.0            None
#
#                                               params  split0_test_score  \
# 0  {'n_estimators': 200, 'min_samples_split': 10,...          -0.388472
# 1  {'n_estimators': 100, 'min_samples_split': 15,...          -0.482474
# 2  {'n_estimators': 50, 'min_samples_split': 15, ...          -0.448148
# 3  {'n_estimators': 200, 'min_samples_split': 2, ...          -0.405261
# 4  {'n_estimators': 50, 'min_samples_split': 15, ...          -0.381865
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.317604          -0.265093          -0.309479          -0.309062
# 1          -0.424250          -0.394840          -0.437785          -0.459167
# 2          -0.404994          -0.367463          -0.398159          -0.418188
# 3          -0.337807          -0.290895          -0.326593          -0.350929
# 4          -0.305575          -0.257186          -0.305187          -0.291160
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.317942        0.039795                2
# 1        -0.439703        0.029878                5
# 2        -0.407390        0.026317                4
# 3        -0.342297        0.037277                3
# 4        -0.308195        0.040830                1

# %%
# A Good Model
good_model = RandomForestRegressor(n_estimators  =100, min_samples_leaf = 7, min_samples_split = 4, 
                                  max_features= 0.5, n_jobs = -1, max_depth = None, max_samples =None)
good_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_features=0.5, min_samples_leaf=7, min_samples_split=4,
#                       n_jobs=-1)

# %%
CalculatePerformance(good_model, X_train, X_test, y_train, y_test)
# Out:
# {'Train R2': 0.9392485219124626,
#  'Test R2': 0.8794790674820775,
#  'Train MAE': 3554.0469996664106,
#  'Test MAE': 5950.141483280706,
#  'Train RMSLE': 0.17276096157037943,
#  'Test RMSLE': 0.2438809815242914}
